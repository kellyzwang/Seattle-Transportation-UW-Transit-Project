# %% [markdown]
# # Stops and Routes Near UW
#
# For Data 511 (Data Viz) Seattle Transportation Group Project

# %%
# import packages
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import time, folium
from folium.plugins import MarkerCluster
from folium import PolyLine
from pyproj import Geod
from geopy.distance import geodesic

# %% [markdown]
# # Step 1: Create a Map Centered on UW and an Overlay Bounding Box

# %%
# Create a Map Centered on UW 

#UW lat/long from here: https://www.latlong.net/place/university-of-washington-seattle-wa-usa-12555.html
UW_LAT = 47.655548
UW_LON = -122.303200



UW_MAP = folium.Map(location=[UW_LAT, UW_LON], zoom_start=14)
UW_MAP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_824e6781fe1ed8a9cb4f97caa90f1be2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_824e6781fe1ed8a9cb4f97caa90f1be2 = L.map(
#                 &quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot;,
#                 {
#                     center: [47.655548, -122.3032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2b7f1272646ccb6c259b5e686b4cf54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Create a bounding box around UW 

BOX_SCALE = 0.4 # scale in miles 

# translate scale in miles to lat_lon degrees from here: 
# https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
lat_scale = float(BOX_SCALE)*(1.0/69.0)    
lon_scale = float(BOX_SCALE)*(1.0/46.54) # cacluated from https://latlongdata.com/distance-calculator/


# calc max/min lat and long for box
min_lat = UW_LAT - lat_scale
max_lat = UW_LAT + lat_scale
min_lon = UW_LON - lon_scale
max_lon = UW_LON + lon_scale


# bounding points
upper_left = (max_lat, min_lon)
upper_right = (max_lat, max_lon) 
lower_right = (min_lat, min_lon)
lower_left = (min_lat, max_lon) 

print(f"Max Lat is_{round(max_lat, 4)} Min Lat is_{round(min_lat, 4)}") 
print(f"Max Lon is_{round(max_lon, 4)} Min Lon is_{round(min_lon, 4)}")
# Out:
# Max Lat is_47.6613 Min Lat is_47.6498
# Max Lon is_-122.2946 Min Lon is_-122.3118

# %%
# Draw the bounding box on the map 


# Create a rectangle using the min and max latitude and longitude values
rectangle = folium.Rectangle(
    bounds = [upper_left, upper_right, lower_right, lower_left],
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=.2,
)


# Add the rectangle to the map
rectangle.add_to(UW_MAP)

# Display Map
UW_MAP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_824e6781fe1ed8a9cb4f97caa90f1be2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_824e6781fe1ed8a9cb4f97caa90f1be2 = L.map(
#                 &quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot;,
#                 {
#                     center: [47.655548, -122.3032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2b7f1272646ccb6c259b5e686b4cf54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#             var rectangle_85307958cb95f220f5ebda12c320f0d5 = L.rectangle(
#                 [[47.66134510144928, -122.31179475719811], [47.66134510144928, -122.2946052428019], [47.64975089855073, -122.31179475719811], [47.64975089855073, -122.2946052428019]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Questions to discuss.
#
# We may want to move the bounding box east to cover more of Udistrict and eless of hte Union Bay Area?
# Should box be bigger, smaller?

# %% [markdown]
# # Step 2: Now let's find the stops near UW

# %%
# reprint here the max/min lon/lat of the bounding box for easy reference
print(f"Max Lat is_{round(max_lat, 4)} Min Lat is_{round(min_lat, 4)}") 
print(f"Max Lon is_{round(max_lon, 4)} Min Lon is_{round(min_lon, 4)}")
# Out:
# Max Lat is_47.6613 Min Lat is_47.6498
# Max Lon is_-122.2946 Min Lon is_-122.3118

# %%
# load bus and route data cleaned 
path = "C:/Users/suetb/OneDrive - UW/Data511/Group Project/Bus_Route.csv"
routes = pd.read_csv(path)
routes.rename(columns={'X': 'LON'}, inplace=True)
routes.rename(columns={'Y': 'LAT'}, inplace=True)
print(routes.shape)
routes.head()
# Out:
# (9846, 4)
#           LON        LAT  STOP_ID BUS_NUM
# 0 -122.222391  47.343924    58235     160
# 1 -122.223371  47.347723    58240     160
# 2 -122.222411  47.339827    58255     160
# 3 -122.222390  47.335523    58257     160
# 4 -122.221679  47.331698    58260     160

# %%
# Function that returns true if the stop is in the bounding box based on stop lat/long
# otherwise false

def stop_in_box (stop_lat, stop_lon, min_lat, max_lat, min_lon, max_lon):
    result = (stop_lat >  min_lat) & (stop_lat < max_lat) & (stop_lon > min_lon) & (stop_lon < max_lon)
    return result

# %%
# calculate whether stop in bounding box 

n= routes.shape[0]
near_UW_all = []

for i in range(n):
    stop_lat = routes.iloc[i]["LAT"]
    stop_lon = routes.iloc[i]["LON"]
    near_UW = stop_in_box(stop_lat, stop_lon, min_lat, max_lat, min_lon, max_lon)
    #print(near_UW)
    near_UW_all.append(near_UW)

routes["STOP_IS_NEAR_UW"] = near_UW_all
print()
routes.head()
# Out:
#           LON        LAT  STOP_ID BUS_NUM  STOP_IS_NEAR_UW
# 0 -122.222391  47.343924    58235     160            False
# 1 -122.223371  47.347723    58240     160            False
# 2 -122.222411  47.339827    58255     160            False
# 3 -122.222390  47.335523    58257     160            False
# 4 -122.221679  47.331698    58260     160            False

# %%
# how many stops are near UW? 
stops_near_UW = routes[routes["STOP_IS_NEAR_UW"]]
num =len(stops_near_UW["STOP_ID"].drop_duplicates())
print(f"{num}_stops are near UW")
stops_near_UW.head()
# Out:
# 26_stops are near UW
#              LON        LAT  STOP_ID BUS_NUM  STOP_IS_NEAR_UW
# 574  -122.304086  47.650498    25755     255             True
# 575  -122.303491  47.651546    25765      65             True
# 1289 -122.298579  47.660850    25790      65             True
# 1861 -122.310879  47.652085    29240     255             True
# 1862 -122.306906  47.650504    29242     44N             True

# %%
# Function that calculates distance in miles to center of UW - in case we want to change bounding area later 

# ATTRIBUTION NOTE: This function is adapted from code provided by Professor McDonald 
# in a notebook entitled "wildfire_geo_proximity_example.ipbny."  and made available to students
# in Data 512 under a CC-BY 4.0 license 

def calc_point_dist(p1_long, p1_lat, p2_long, p2_lat):
    geodcalc = Geod(ellps='WGS84') 
    distance = geodcalc.inv(p1_long,p1_lat, p2_long, p2_lat)
    d_meters = distance[2]
    d_miles = d_meters * 0.00062137 # constant to convert meters to miles
    return d_miles

# %%
n= routes.shape[0]
dist_to_UW_all = []

for i in range(n):
    stop_lat = routes.iloc[i]["LAT"]
    stop_lon = routes.iloc[i]["LON"]
    dist_to_UW = calc_point_dist(stop_lon, stop_lat, UW_LON, UW_LAT)
    #print(dist_to_UW)
    dist_to_UW_all.append(dist_to_UW)

routes["DIST_TO_UW"] = dist_to_UW_all

# %%
# Check - If I did this right, the stops selected as "TRUE" by bounding box method
# Should all be within the specified distance to UW * sqrt(2) 
# The sqrt(2) is because I used a box instead of circle - so corner of box further than radial distance
stops_near_UW = routes[routes["STOP_IS_NEAR_UW"]]
stops_near_UW.head()
# Out:
#              LON        LAT  STOP_ID BUS_NUM  STOP_IS_NEAR_UW  DIST_TO_UW
# 574  -122.304086  47.650498    25755     255             True    0.351326
# 575  -122.303491  47.651546    25765      65             True    0.276814
# 1289 -122.298579  47.660850    25790      65             True    0.425054
# 1861 -122.310879  47.652085    29240     255             True    0.430978
# 1862 -122.306906  47.650504    29242     44N             True    0.389037

# %%
# Check any stops that seem too far 
max_dist = 2**(1/2)*BOX_SCALE
stops_near_UW[stops_near_UW["DIST_TO_UW"] > max_dist]
# Out:
# Empty DataFrame
# Columns: [LON, LAT, STOP_ID, BUS_NUM, STOP_IS_NEAR_UW, DIST_TO_UW]
# Index: []

# %% [markdown]
# All Looks OK. Dataframe empty as expected.

# %%
# Now let's plot stops near UW on a map 

n = stops_near_UW.shape[0]
for i in range (n): 
    dat = stops_near_UW.iloc[i]
    name = dat["STOP_ID"]
    lat = dat["LAT"]
    lon = dat["LON"]
    latlon = (lat, lon)
    folium.Marker(location=latlon, popup=name).add_to(UW_MAP)

UW_MAP
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_824e6781fe1ed8a9cb4f97caa90f1be2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_824e6781fe1ed8a9cb4f97caa90f1be2 = L.map(
#                 &quot;map_824e6781fe1ed8a9cb4f97caa90f1be2&quot;,
#                 {
#                     center: [47.655548, -122.3032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2b7f1272646ccb6c259b5e686b4cf54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#             var rectangle_85307958cb95f220f5ebda12c320f0d5 = L.rectangle(
#                 [[47.66134510144928, -122.31179475719811], [47.66134510144928, -122.2946052428019], [47.64975089855073, -122.31179475719811], [47.64975089855073, -122.2946052428019]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#             var marker_96dd5a458eb247d6834bfd028b3028d3 = L.marker(
#                 [47.65049802, -122.304086],
#                 {}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#         var popup_fd1e9e3edf50178c43c155731429dccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d6c1f88a1f416bd4597139f0fbe4337 = $(`&lt;div id=&quot;html_5d6c1f88a1f416bd4597139f0fbe4337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;25755&lt;/div&gt;`)[0];
#                 popup_fd1e9e3edf50178c43c155731429dccf.setContent(html_5d6c1f88a1f416bd4597139f0fbe4337);
#
#
#
#         marker_96dd5a458eb247d6834bfd028b3028d3.bindPopup(popup_fd1e9e3edf50178c43c155731429dccf)
#         ;
#
#
#
#
#             var marker_cb33a5eeaba96838eeabee5ec443a83f = L.marker(
#                 [47.65154602, -122.3034907],
#                 {}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#         var popup_0f27db4e90a9d7099212125bf9590ded = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_727388513ba0a42a1eaf26caff0255b4 = $(`&lt;div id=&quot;html_727388513ba0a42a1eaf26caff0255b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;25765&lt;/div&gt;`)[0];
#                 popup_0f27db4e90a9d7099212125bf9590ded.setContent(html_727388513ba0a42a1eaf26caff0255b4);
#
#
#
#         marker_cb33a5eeaba96838eeabee5ec443a83f.bindPopup(popup_0f27db4e90a9d7099212125bf9590ded)
#         ;
#
#
#
#
#             var marker_49e77840c6ed1c7a3c93fa15877fbe16 = L.marker(
#                 [47.66084953, -122.2985789],
#                 {}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#         var popup_fca89af2749b36b62b9deed73893627d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c8e91398a1be06f6d357d1e8ad86614 = $(`&lt;div id=&quot;html_9c8e91398a1be06f6d357d1e8ad86614&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;25790&lt;/div&gt;`)[0];
#                 popup_fca89af2749b36b62b9deed73893627d.setContent(html_9c8e91398a1be06f6d357d1e8ad86614);
#
#
#
#         marker_49e77840c6ed1c7a3c93fa15877fbe16.bindPopup(popup_fca89af2749b36b62b9deed73893627d)
#         ;
#
#
#
#
#             var marker_8eba5dbe2e20ca700205ebf357b02f1a = L.marker(
#                 [47.65208488, -122.3108794],
#                 {}
#             ).addTo(map_824e6781fe1ed8a9cb4f97caa90f1be2);
#
#
#         var popup_11dc2ee98cbd475b882be4b9ece428d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e175627a9a75cc30518578b20427b18f = $(`&lt;div id=&quot;html_e175627a9a75cc30518578b20427b18f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29240&lt;/div&gt;`)[0];
#                 popup_11dc2ee98cbd475b882be4b9ece428d9.setContent(html_e175627a9a75cc30518578b20427b18f);
#
#
#
#         marker_8eba5dbe2e20ca700205ebf357b02f1a.bindPopup(popup_11dc2ee98cbd475b882be4b9ece428d9)
#         ;
#
#
#
#
#             var marker_06708ead10259805108933311d9f5508 = L.marker(
#                 [47.650504

# %%
# Save MAP to html file 
UW_MAP.save('UW_map_with_bus_stops.html')

# %% [markdown]
# # Step 3: Find all the routes that have stops near UW

# %%
UW_buses = stops_near_UW["BUS_NUM"].drop_duplicates()
num_buses = UW_buses.shape 
bus_names = UW_buses.to_list() 
bus_names_sorted = sorted(bus_names)
print(f"{num_buses[0]} Busses Service UW")
print(f"Bus Routes Servicing UW include_{bus_names_sorted}")
# Out:
# 21 Busses Service UW
# Bus Routes Servicing UW include_['255', '271', '271N', '31', '32', '372E', '372EN', '43', '44', '44N', '45', '48', '542E', '556E', '65', '67', '73', '75', '982E', '988E', '988EN']

# %%
# Add an indicator whether the route has a stop near UW

n= routes.shape[0]
route_has_stop_all = []

for i in range(n): 
    bus_name = routes.iloc[i]['BUS_NUM']
    route_has_stop = bus_name in bus_names
    route_has_stop_all.append(route_has_stop)

routes["ROUTE_SERVES_UW"] = route_has_stop_all
routes.head()
# Out:
#           LON        LAT  STOP_ID BUS_NUM  STOP_IS_NEAR_UW  DIST_TO_UW  \
# 0 -122.222391  47.343924    58235     160            False   21.858179
# 1 -122.223371  47.347723    58240     160            False   21.591751
# 2 -122.222411  47.339827    58255     160            False   22.136872
# 3 -122.222390  47.335523    58257     160            False   22.430102
# 4 -122.221679  47.331698    58260     160            False   22.696178
#
#    ROUTE_SERVES_UW
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
# Now filter the route dataset to include only the buses that have  a stop near UW 
routes_filtered = routes[routes["ROUTE_SERVES_UW"]]
routes_filtered = routes_filtered.sort_values(by='BUS_NUM')
print(routes_filtered.shape)
routes_filtered.head()
# Out:
# (1084, 7)
#              LON        LAT  STOP_ID BUS_NUM  STOP_IS_NEAR_UW  DIST_TO_UW  \
# 6084 -122.194316  47.644278    74442     255            False    5.142298
# 6364 -122.185245  47.714881    74734     255            False    6.861687
# 6385 -122.191070  47.711257    74071     255            False    6.494479
# 6386 -122.193585  47.711256    74072     255            False    6.400310
# 2415 -122.313492  47.655921     9575     255            False    0.481116
#
#       ROUTE_SERVES_UW
# 6084             True
# 6364             True
# 6385             True
# 6386             True
# 2415             True

# %%
# create clean map w/ no bounding box  
UW_MAP2 = folium.Map(location=[UW_LAT, UW_LON], zoom_start=14)

# %%
# Define a function to add a route to the map 

def map_route(this_route):     
    # Add stops to the map with popups
    for index, row in this_route.iterrows():
        folium.Marker([row['LAT'], row['LON']], popup=f"STOP_ID: {row['STOP_ID']}").add_to(UW_MAP2)

    # Connect stops with lines
    #folium.PolyLine(locations=this_route[['Y', 'X']].values, color='blue').add_to(UW_MAP2)

# %%
# Map a route 

this_bus_name = bus_names[0]
print(this_bus_name)
this_route = routes_filtered[routes_filtered['BUS_NUM'] == this_bus_name]
map_route(this_route)
UW_MAP2
# Out:
# 255
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77fcbd78bc691f514f398758b2039784 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77fcbd78bc691f514f398758b2039784&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77fcbd78bc691f514f398758b2039784 = L.map(
#                 &quot;map_77fcbd78bc691f514f398758b2039784&quot;,
#                 {
#                     center: [47.655548, -122.3032],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_510c9ff7e7440bd6b09d50973f633726 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#             var marker_ed3be2d7012e5a1b1f1121fc9d967a11 = L.marker(
#                 [47.64427784, -122.194316],
#                 {}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#         var popup_45d095ab1fa4b43d6b9aecc50c421db0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_538512c44a7f2cdc81cc6f209242c180 = $(`&lt;div id=&quot;html_538512c44a7f2cdc81cc6f209242c180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STOP_ID: 74442&lt;/div&gt;`)[0];
#                 popup_45d095ab1fa4b43d6b9aecc50c421db0.setContent(html_538512c44a7f2cdc81cc6f209242c180);
#
#
#
#         marker_ed3be2d7012e5a1b1f1121fc9d967a11.bindPopup(popup_45d095ab1fa4b43d6b9aecc50c421db0)
#         ;
#
#
#
#
#             var marker_2e23962ab55dcf0aa4f44ba82e214128 = L.marker(
#                 [47.71488086, -122.1852454],
#                 {}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#         var popup_2608830d066cb9b897adfb610a6d8a24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3970ee38bf142b5e8fb9632a91a879ab = $(`&lt;div id=&quot;html_3970ee38bf142b5e8fb9632a91a879ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STOP_ID: 74734&lt;/div&gt;`)[0];
#                 popup_2608830d066cb9b897adfb610a6d8a24.setContent(html_3970ee38bf142b5e8fb9632a91a879ab);
#
#
#
#         marker_2e23962ab55dcf0aa4f44ba82e214128.bindPopup(popup_2608830d066cb9b897adfb610a6d8a24)
#         ;
#
#
#
#
#             var marker_ddbaed8cd50eb184605ea72532630bb6 = L.marker(
#                 [47.71125732, -122.1910702],
#                 {}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#         var popup_b91b08f435abc8973d6db2b3aaeebeb5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad5e9358b0005337bfb65c49f2c0dcd4 = $(`&lt;div id=&quot;html_ad5e9358b0005337bfb65c49f2c0dcd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STOP_ID: 74071&lt;/div&gt;`)[0];
#                 popup_b91b08f435abc8973d6db2b3aaeebeb5.setContent(html_ad5e9358b0005337bfb65c49f2c0dcd4);
#
#
#
#         marker_ddbaed8cd50eb184605ea72532630bb6.bindPopup(popup_b91b08f435abc8973d6db2b3aaeebeb5)
#         ;
#
#
#
#
#             var marker_2c26aeaac8e363a9f0c0de714df430e5 = L.marker(
#                 [47.71125613, -122.1935849],
#                 {}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#         var popup_bf8974d93e83845e4ffd44c2867585dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d015b69212fcf2abe5f6f2035ef9b869 = $(`&lt;div id=&quot;html_d015b69212fcf2abe5f6f2035ef9b869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STOP_ID: 74072&lt;/div&gt;`)[0];
#                 popup_bf8974d93e83845e4ffd44c2867585dd.setContent(html_d015b69212fcf2abe5f6f2035ef9b869);
#
#
#
#         marker_2c26aeaac8e363a9f0c0de714df430e5.bindPopup(popup_bf8974d93e83845e4ffd44c2867585dd)
#         ;
#
#
#
#
#             var marker_23fd7e7f785a72599ca271edce023b95 = L.marker(
#                 [47.65592127, -122.3134924],
#                 {}
#             ).addTo(map_77fcbd78bc691f514f398758b2039784);
#
#
#         var popup_e0b35e2b75fcd4b233b807f4eff72f34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e8e9bed3f5e842e4461c3a902bd1a0e = $(`&lt;div id=&quot;html_7e8e9bed3f5e842e4461c3a902bd1a0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STOP_ID: 9575&lt;/div&gt;`)[0];
#                 popup_e0b35e2b75fcd4b233b807f4eff72f34.setContent(html_7e8e9bed3f5e842e4461c3a902bd1a0e);
#
#
#
#         marker_23fd7e7f785a72599ca271edce023b95.bindPopup(popup_e0b35e2b75fcd4b233b807f4eff72f34)
#         ;
#
#
#
#
#             var marker_9edb203620639cd2d94b6bac0a95f87a = L.marker(
#                 [47.71126208

# %%
# Save MAP to html file 
f = f"Example Route Map for Bus_{this_bus_name}.html"
UW_MAP2.save(f)

# %%
# Save filtered routes to CSV 
f = "Bus_Route_Filtered.csv"
routes_filtered.to_csv(f)
